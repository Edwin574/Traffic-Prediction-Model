# %%
import pandas as pd
import numpy as np

# %%
traffic = pd.read_csv("DataSet/traffic/traffic.csv")
traffic
# Out:
#                   DateTime  Junction  Vehicles           ID
# 0      2015-11-01 00:00:00         1        15  20151101001
# 1      2015-11-01 01:00:00         1        13  20151101011
# 2      2015-11-01 02:00:00         1        10  20151101021
# 3      2015-11-01 03:00:00         1         7  20151101031
# 4      2015-11-01 04:00:00         1         9  20151101041
# ...                    ...       ...       ...          ...
# 48115  2017-06-30 19:00:00         4        11  20170630194
# 48116  2017-06-30 20:00:00         4        30  20170630204
# 48117  2017-06-30 21:00:00         4        16  20170630214
# 48118  2017-06-30 22:00:00         4        22  20170630224
# 48119  2017-06-30 23:00:00         4        12  20170630234
#
# [48120 rows x 4 columns]

# %%
traffic["DateTime"] = pd.to_datetime(traffic["DateTime"])
traffic.head()
# Out:
#              DateTime  Junction  Vehicles           ID
# 0 2015-11-01 00:00:00         1        15  20151101001
# 1 2015-11-01 01:00:00         1        13  20151101011
# 2 2015-11-01 02:00:00         1        10  20151101021
# 3 2015-11-01 03:00:00         1         7  20151101031
# 4 2015-11-01 04:00:00         1         9  20151101041

# %%
traffic = traffic.reset_index(drop=True)

# %%
traffic = traffic.set_index("DateTime")
traffic
# Out:
#                      Junction  Vehicles           ID
# DateTime
# 2015-11-01 00:00:00         1        15  20151101001
# 2015-11-01 01:00:00         1        13  20151101011
# 2015-11-01 02:00:00         1        10  20151101021
# 2015-11-01 03:00:00         1         7  20151101031
# 2015-11-01 04:00:00         1         9  20151101041
# ...                       ...       ...          ...
# 2017-06-30 19:00:00         4        11  20170630194
# 2017-06-30 20:00:00         4        30  20170630204
# 2017-06-30 21:00:00         4        16  20170630214
# 2017-06-30 22:00:00         4        22  20170630224
# 2017-06-30 23:00:00         4        12  20170630234
#
# [48120 rows x 3 columns]

# %%
traffic = traffic.drop("ID", axis=1)
traffic
# Out:
#                      Junction  Vehicles
# DateTime
# 2015-11-01 00:00:00         1        15
# 2015-11-01 01:00:00         1        13
# 2015-11-01 02:00:00         1        10
# 2015-11-01 03:00:00         1         7
# 2015-11-01 04:00:00         1         9
# ...                       ...       ...
# 2017-06-30 19:00:00         4        11
# 2017-06-30 20:00:00         4        30
# 2017-06-30 21:00:00         4        16
# 2017-06-30 22:00:00         4        22
# 2017-06-30 23:00:00         4        12
#
# [48120 rows x 2 columns]

# %%
data_junc1 = traffic[traffic.Junction == 1]
data_junc1
# Out:
#                      Junction  Vehicles
# DateTime
# 2015-11-01 00:00:00         1        15
# 2015-11-01 01:00:00         1        13
# 2015-11-01 02:00:00         1        10
# 2015-11-01 03:00:00         1         7
# 2015-11-01 04:00:00         1         9
# ...                       ...       ...
# 2017-06-30 19:00:00         1       105
# 2017-06-30 20:00:00         1        96
# 2017-06-30 21:00:00         1        90
# 2017-06-30 22:00:00         1        84
# 2017-06-30 23:00:00         1        78
#
# [14592 rows x 2 columns]

# %%
data_junc2 = traffic[traffic.Junction == 2]
data_junc2
# Out:
#                      Junction  Vehicles
# DateTime
# 2015-11-01 00:00:00         2         6
# 2015-11-01 01:00:00         2         6
# 2015-11-01 02:00:00         2         5
# 2015-11-01 03:00:00         2         6
# 2015-11-01 04:00:00         2         7
# ...                       ...       ...
# 2017-06-30 19:00:00         2        34
# 2017-06-30 20:00:00         2        35
# 2017-06-30 21:00:00         2        31
# 2017-06-30 22:00:00         2        29
# 2017-06-30 23:00:00         2        27
#
# [14592 rows x 2 columns]

# %%
data_junc3 = traffic[traffic.Junction == 3]
data_junc3
# Out:
#                      Junction  Vehicles
# DateTime
# 2015-11-01 00:00:00         3         9
# 2015-11-01 01:00:00         3         7
# 2015-11-01 02:00:00         3         5
# 2015-11-01 03:00:00         3         1
# 2015-11-01 04:00:00         3         2
# ...                       ...       ...
# 2017-06-30 19:00:00         3        33
# 2017-06-30 20:00:00         3        31
# 2017-06-30 21:00:00         3        28
# 2017-06-30 22:00:00         3        26
# 2017-06-30 23:00:00         3        39
#
# [14592 rows x 2 columns]

# %%
data_junc4 = traffic[traffic.Junction == 4]
data_junc4
# Out:
#                      Junction  Vehicles
# DateTime
# 2017-01-01 00:00:00         4         3
# 2017-01-01 01:00:00         4         1
# 2017-01-01 02:00:00         4         4
# 2017-01-01 03:00:00         4         4
# 2017-01-01 04:00:00         4         2
# ...                       ...       ...
# 2017-06-30 19:00:00         4        11
# 2017-06-30 20:00:00         4        30
# 2017-06-30 21:00:00         4        16
# 2017-06-30 22:00:00         4        22
# 2017-06-30 23:00:00         4        12
#
# [4344 rows x 2 columns]

# %%
data_junc4["Vehicles"].sum(), data_junc3["Vehicles"].sum(), data_junc2["Vehicles"].sum(), data_junc1["Vehicles"].sum()
# Out:
# (31501, 199823, 207983, 657412)

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48120 entries, 2015-11-01 00:00:00 to 2017-06-30 23:00:00
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Junction  48120 non-null  int64
#  1   Vehicles  48120 non-null  int64
# dtypes: int64(2)
# memory usage: 1.1 MB

# %%
data_junc1["year"] = year
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7888\2496964504.py in <module>
# ----> 1 data_junc1["year"] = year
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
# ...

# %%
data_junc1.index.year

# %%
year = data_junc1.index.year
year
# Out:
# Int64Index([2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015,
#             ...
#             2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017],
#            dtype='int64', name='DateTime', length=14592)

# %%
data_junc1
# Out:
#                      Junction  Vehicles
# DateTime
# 2015-11-01 00:00:00         1        15
# 2015-11-01 01:00:00         1        13
# 2015-11-01 02:00:00         1        10
# 2015-11-01 03:00:00         1         7
# 2015-11-01 04:00:00         1         9
# ...                       ...       ...
# 2017-06-30 19:00:00         1       105
# 2017-06-30 20:00:00         1        96
# 2017-06-30 21:00:00         1        90
# 2017-06-30 22:00:00         1        84
# 2017-06-30 23:00:00         1        78
#
# [14592 rows x 2 columns]

# %%
year = data_junc2.index.year

data_junc2["year"] = year

data_junc2
# Out:
# C:\Users\ronni\AppData\Local\Temp\ipykernel_7888\3956731354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_junc2["year"] = year
#                      Junction  Vehicles  year
# DateTime
# 2015-11-01 00:00:00         2         6  2015
# 2015-11-01 01:00:00         2         6  2015
# 2015-11-01 02:00:00         2         5  2015
# 2015-11-01 03:00:00         2         6  2015
# 2015-11-01 04:00:00         2         7  2015
# ...                       ...       ...   ...
# 2017-06-30 19:00:00         2        34  2017
# 2017-06-30 20:00:00         2        35  2017
# 2017-06-30 21:00:00         2        31  2017
# 2017-06-30 22:00:00         2        29  2017
# 2017-06-30 23:00:00         2        27  2017
#
# ...

# %%
year = data_junc3.index.year

data_junc3["year"] = year

data_junc3
# Out:
# C:\Users\ronni\AppData\Local\Temp\ipykernel_7888\3300997387.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_junc3["year"] = year
#                      Junction  Vehicles  year
# DateTime
# 2015-11-01 00:00:00         3         9  2015
# 2015-11-01 01:00:00         3         7  2015
# 2015-11-01 02:00:00         3         5  2015
# 2015-11-01 03:00:00         3         1  2015
# 2015-11-01 04:00:00         3         2  2015
# ...                       ...       ...   ...
# 2017-06-30 19:00:00         3        33  2017
# 2017-06-30 20:00:00         3        31  2017
# 2017-06-30 21:00:00         3        28  2017
# 2017-06-30 22:00:00         3        26  2017
# 2017-06-30 23:00:00         3        39  2017
#
# ...

# %%
year = data_junc4.index.year

data_junc4["year"] = year

data_junc4
# Out:
# C:\Users\ronni\AppData\Local\Temp\ipykernel_7888\417384698.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_junc4["year"] = year
#                      Junction  Vehicles  year
# DateTime
# 2017-01-01 00:00:00         4         3  2017
# 2017-01-01 01:00:00         4         1  2017
# 2017-01-01 02:00:00         4         4  2017
# 2017-01-01 03:00:00         4         4  2017
# 2017-01-01 04:00:00         4         2  2017
# ...                       ...       ...   ...
# 2017-06-30 19:00:00         4        11  2017
# 2017-06-30 20:00:00         4        30  2017
# 2017-06-30 21:00:00         4        16  2017
# 2017-06-30 22:00:00         4        22  2017
# 2017-06-30 23:00:00         4        12  2017
#
# ...

# %%
data_junc1.to_csv("Traffic_Junc/Junc1.csv")
data_junc2.to_csv("Traffic_Junc/Junc2.csv")
data_junc3.to_csv("Traffic_Junc/Junc3.csv")
data_junc4.to_csv("Traffic_Junc/Junc4.csv")
